# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = 'Test2-data.xlsx'

# %%
df = pd.read_excel(file, skiprows=1)

# %%
df
# Out:
#                                       Province/Territory Program Stream  \
# 0                              Newfoundland and Labrador      High Wage
# 1                              Newfoundland and Labrador      High Wage
# 2                              Newfoundland and Labrador      High Wage
# 3                              Newfoundland and Labrador      High Wage
# 4                              Newfoundland and Labrador      High Wage
# ...                                                  ...            ...
# 18561  3. The employer name is manually entered in th...            NaN
# 18562  4. Effective November 2016, NOC 2011 is being ...            NaN
# 18563  5. Effective February 2018, LMIAs in support o...            NaN
# 18564  6. The LMIA System tracks TFW positions only, ...            NaN
# 18565  7. The numbers appearing in this release may d...            NaN
#
#                                 Employer                          Address  \
# ...

# %% [markdown]
# # Question 2

# %%
df = df[:18558]
df
# Out:
#                                       Province/Territory  \
# 0                              Newfoundland and Labrador
# 1                              Newfoundland and Labrador
# 2                              Newfoundland and Labrador
# 3                              Newfoundland and Labrador
# 4                              Newfoundland and Labrador
# ...                                                  ...
# 18553  Employers carrying on business in Canada with ...
# 18554  Employers carrying on business in Canada with ...
# 18555  Employers carrying on business in Canada with ...
# 18556  Employers carrying on business in Canada with ...
# 18557  Employers carrying on business in Canada with ...
#
#               Program Stream                           Employer  \
# 0                  High Wage                    AB Complex Inc.
# 1                  High Wage                     Body Quest Inc
# 2                  High Wage                     Central Health
# ...

# %%
df.tail()
# Out:
#                                       Province/Territory  \
# 18553  Employers carrying on business in Canada with ...
# 18554  Employers carrying on business in Canada with ...
# 18555  Employers carrying on business in Canada with ...
# 18556  Employers carrying on business in Canada with ...
# 18557  Employers carrying on business in Canada with ...
#
#               Program Stream                       Employer  \
# 18553               Low Wage        Sea Sun Navigation S.A.
# 18554    Primary Agriculture                 A-Z Harvesting
# 18555    Primary Agriculture             Hennessey Brothers
# 18556    Primary Agriculture  Kennedy's Harvesting & Mowing
# 18557    Primary Agriculture                       KZS, LLC
#
#                  Address                                         Occupation  \
# 18553     Panama City, .                                         6322-Cooks
# 18554  Harrington, 04643  8252-Agricultural service contractors, farm su...
# ...

# %%
Atlantic_Canada = ["Newfoundland and Labrador", "Prince Edward Island", "Nova Scotia",
"New Brunswick"]

# %%
df = df[df['Province/Territory'].isin(Atlantic_Canada)]
df
# Out:
#             Province/Territory         Program Stream  \
# 0    Newfoundland and Labrador              High Wage
# 1    Newfoundland and Labrador              High Wage
# 2    Newfoundland and Labrador              High Wage
# 3    Newfoundland and Labrador              High Wage
# 4    Newfoundland and Labrador              High Wage
# ..                         ...                    ...
# 408              New Brunswick   Global Talent Stream
# 409              New Brunswick   Global Talent Stream
# 410              New Brunswick   Global Talent Stream
# 411              New Brunswick   Global Talent Stream
# 412              New Brunswick   Global Talent Stream
#
#                               Employer                          Address  \
# 0                      AB Complex Inc.               Gander, NL A1V 1X3
# 1                       Body Quest Inc             Paradise, NL A1L 1V1
# 2                       Central Health  Grand Falls-Windsor, NL A2A 1Y4
# ...

# %%
df['Occupation'].str[0]
# Out:
# 0      0
# 1      3
# 2      3
# 3      3
# 4      0
#       ..
# 408    2
# 409    (
# 410    2
# 411    2
# 412    2
# Name: Occupation, Length: 413, dtype: object

# %% [markdown]
# # Isolation of 1st digit from NOC

# %%
df.loc[:, 'Occupation'] = df['Occupation'].str[0]

# %%
# df['Occupation'] = df['Occupation'].str[0]

# %%
df
# Out:
#             Province/Territory         Program Stream  \
# 0    Newfoundland and Labrador              High Wage
# 1    Newfoundland and Labrador              High Wage
# 2    Newfoundland and Labrador              High Wage
# 3    Newfoundland and Labrador              High Wage
# 4    Newfoundland and Labrador              High Wage
# ..                         ...                    ...
# 408              New Brunswick   Global Talent Stream
# 409              New Brunswick   Global Talent Stream
# 410              New Brunswick   Global Talent Stream
# 411              New Brunswick   Global Talent Stream
# 412              New Brunswick   Global Talent Stream
#
#                               Employer                          Address  \
# 0                      AB Complex Inc.               Gander, NL A1V 1X3
# 1                       Body Quest Inc             Paradise, NL A1L 1V1
# 2                       Central Health  Grand Falls-Windsor, NL A2A 1Y4
# ...

# %%
df[df['Occupation'] == '(']
# Out:
#     Province/Territory         Program Stream  \
# 272        Nova Scotia   Global Talent Stream
# 409      New Brunswick   Global Talent Stream
#
#                                          Employer                     Address  \
# 272  Nova Scotia Power Maritime Link Incorporated         Halifax, NS B3J 3A8
# 409                        Cooke Aquaculture Inc.  Blacks Harbour, NB E5H 1K1
#
#     Occupation Incorporate Status  Approved LMIAs  Approved Positions
# 272          (            Unknown             1.0                 1.0
# 409          (            Unknown             1.0                 1.0

# %% [markdown]
# # Calculation of count of NOC categories

# %%
# Discarding blanks

# %%
df.drop(df[df['Occupation'] == '('].index,inplace=True)
# Out:
# C:\Users\ZenBook\AppData\Local\Temp\ipykernel_8264\1447660345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[df['Occupation'] == '('].index,inplace=True)

# %%
df
# Out:
#             Province/Territory         Program Stream  \
# 0    Newfoundland and Labrador              High Wage
# 1    Newfoundland and Labrador              High Wage
# 2    Newfoundland and Labrador              High Wage
# 3    Newfoundland and Labrador              High Wage
# 4    Newfoundland and Labrador              High Wage
# ..                         ...                    ...
# 407              New Brunswick    Primary Agriculture
# 408              New Brunswick   Global Talent Stream
# 410              New Brunswick   Global Talent Stream
# 411              New Brunswick   Global Talent Stream
# 412              New Brunswick   Global Talent Stream
#
#                               Employer                          Address  \
# 0                      AB Complex Inc.               Gander, NL A1V 1X3
# 1                       Body Quest Inc             Paradise, NL A1L 1V1
# 2                       Central Health  Grand Falls-Windsor, NL A2A 1Y4
# ...

# %%
counts = df['Occupation'].value_counts()
counts
# Out:
# Occupation
# 6    178
# 8     77
# 7     46
# 9     29
# 0     25
# 1     19
# 3     16
# 2     16
# 4      5
# Name: count, dtype: int64

# %%
#plt.bar(counts.index, counts.values)

# %%
counts.sort_index(inplace=True)

# %%
counts
# Out:
# Occupation
# 0     25
# 1     19
# 2     16
# 3     16
# 4      5
# 6    178
# 7     46
# 8     77
# 9     29
# Name: count, dtype: int64

# %%
plt.bar(counts.index, counts.values)
plt.ylabel('# of Position')
plt.xlabel('Category')
plt.title('NOC Category Popularity in Altantic Canada, Q3-2023')
# Out:
# Text(0.5, 1.0, 'NOC Category Popularity in Altantic Canada, Q3-2023')

# %% [markdown]
# # Question 1

# %%
file = 'Test2-data.xlsx'

# %%
df = pd.read_excel(file, skiprows=1)

# %%
df
# Out:
#                                       Province/Territory Program Stream  \
# 0                              Newfoundland and Labrador      High Wage
# 1                              Newfoundland and Labrador      High Wage
# 2                              Newfoundland and Labrador      High Wage
# 3                              Newfoundland and Labrador      High Wage
# 4                              Newfoundland and Labrador      High Wage
# ...                                                  ...            ...
# 18561  3. The employer name is manually entered in th...            NaN
# 18562  4. Effective November 2016, NOC 2011 is being ...            NaN
# 18563  5. Effective February 2018, LMIAs in support o...            NaN
# 18564  6. The LMIA System tracks TFW positions only, ...            NaN
# 18565  7. The numbers appearing in this release may d...            NaN
#
#                                 Employer                          Address  \
# ...

# %%
Atlantic_Canada = ["Newfoundland and Labrador", "Prince Edward Island", "Nova Scotia",
"New Brunswick"]

# %%
df = df[df['Province/Territory'].isin(Atlantic_Canada)]
df
# Out:
#             Province/Territory         Program Stream  \
# 0    Newfoundland and Labrador              High Wage
# 1    Newfoundland and Labrador              High Wage
# 2    Newfoundland and Labrador              High Wage
# 3    Newfoundland and Labrador              High Wage
# 4    Newfoundland and Labrador              High Wage
# ..                         ...                    ...
# 408              New Brunswick   Global Talent Stream
# 409              New Brunswick   Global Talent Stream
# 410              New Brunswick   Global Talent Stream
# 411              New Brunswick   Global Talent Stream
# 412              New Brunswick   Global Talent Stream
#
#                               Employer                          Address  \
# 0                      AB Complex Inc.               Gander, NL A1V 1X3
# 1                       Body Quest Inc             Paradise, NL A1L 1V1
# 2                       Central Health  Grand Falls-Windsor, NL A2A 1Y4
# ...

# %%
# Determine the Top 10 most popular requested occupations from the Occupation field by count

# %%
df['Occupation']
# Out:
# 0      0015-Senior managers - trade, broadcasting and...
# 1      3125-Other professional occupations in health ...
# 2       3112-General practitioners and family physicians
# 3                             3111-Specialist physicians
# 4                           0823-Managers in aquaculture
#                              ...
# 408                2173-Software engineers and designers
# 409                                              (blank)
# 410    2171-Information systems analysts and consultants
# 411                2173-Software engineers and designers
# 412                2173-Software engineers and designers
# Name: Occupation, Length: 413, dtype: object

# %%
count = df['Occupation'].value_counts()
count
# Out:
# Occupation
# 6322-Cooks                                                                       69
# 8431-General farm workers                                                        61
# 6711-Food counter attendants, kitchen helpers and related support occupations    25
# 6311-Food service supervisors                                                    22
# 6211-Retail sales supervisors                                                    17
#                                                                                  ..
# 0821-Managers in agriculture                                                      1
# 2112-Chemists                                                                     1
# 7282-Concrete finishers                                                           1
# 6313-Accommodation, travel, tourism and related services supervisors              1
# 9612-Labourers in metal fabrication                                               1
# Name: count, Length: 90, dtype: int64

# %%
top_10 = count.head(10)
top_10
# Out:
# Occupation
# 6322-Cooks                                                                       69
# 8431-General farm workers                                                        61
# 6711-Food counter attendants, kitchen helpers and related support occupations    25
# 6311-Food service supervisors                                                    22
# 6211-Retail sales supervisors                                                    17
# 7611-Construction trades helpers and labourers                                   14
# 9463-Fish and seafood plant workers                                              11
# 0631-Restaurant and food service managers                                        10
# 9618-Labourers in fish and seafood processing                                     9
# 7511-Transport truck drivers                                                      8
# Name: count, dtype: int64

# %%
# Determine the sum of the rest of the occupations applied for and refer to it as XXXX-Other.

# %%
XXXX_Other = count[11:].sum()
XXXX_Other
# Out:
# 159

# %%
pd.Series({'XXXX-other': XXXX_Other})
# Out:
# XXXX-other    159
# dtype: int64

# %%
top_10_and_other = pd.concat([top_10, pd.Series({'XXXX-other': XXXX_Other})])

# %%
top_10_and_other
# Out:
# 6322-Cooks                                                                        69
# 8431-General farm workers                                                         61
# 6711-Food counter attendants, kitchen helpers and related support occupations     25
# 6311-Food service supervisors                                                     22
# 6211-Retail sales supervisors                                                     17
# 7611-Construction trades helpers and labourers                                    14
# 9463-Fish and seafood plant workers                                               11
# 0631-Restaurant and food service managers                                         10
# 9618-Labourers in fish and seafood processing                                      9
# 7511-Transport truck drivers                                                       8
# XXXX-other                                                                       159
# dtype: int64

# %%
plt.figure(figsize=(6,5))
plt.pie(top_10_and_other, labels = top_10_and_other.index)
plt.title('Top 10 Occupations in Atlantic Canada, Q3-2023')
# Out:
# Text(0.5, 1.0, 'Top 10 Occupations in Atlantic Canada, Q3-2023')
